# %% [markdown]
# # PS4 EDA
#
# ## T MAC
#
# ### Dataset available at: *https://www.kaggle.com/shivamb/all-playstation-4-games*

# %% [markdown]
# # Import Data

# %%
import pandas as pd
import plotly.express as px
from scipy import stats

# %% [markdown]
# ### Correct data types

# %%
data_import = pd.read_csv("playstation_4_games.csv")

data_import["ReleaseDate"] = pd.to_datetime(data_import["ReleaseDate"], format="%Y-%m-%d")
data_import["CompletionTime(Hours)"] = data_import["CompletionTime(Hours)"].str.replace('-', '').str.strip('+').astype('int64', errors='ignore')
data_import
# Out:
#         ID  GamePSID                 GameName            Publisher  \
# 0        1      3045          Q*Bert Rebooted     LOOT Interactive
# 1        2      3051     Q*Bert Rebooted (EU)     LOOT Interactive
# 2        3      6703               Q.U.B.E. 2  Trapped Nerve Games
# 3        4      3403  Q.U.B.E. Director's Cut         GRIP Digital
# 4        5     13176              Quake (PS4)   Bethesda Softworks
# ...    ...       ...                      ...                  ...
# 9681  9682     10928             9th Dawn III            Valorware
# 9682  9683     10929        9th Dawn III (EU)            Valorware
# 9683  9684      7114       n Verlore Verstand      Skobbejak Games
# 9684  9685      7110  n Verlore Verstand (EU)      Skobbejak Games
# 9685  9686     14118       Klang 2 (JP) (PS4)      Ratalaika Games
#
#       ReleaseYear ReleaseDate                                     Developer  \
# 0          2015.0  2015-02-17                                   Gonzo Games
# 1          2015.0  2015-07-22                              LOOT Interactive
# 2          2018.0  2018-03-13                                   Toxic Games
# 3          2015.0  2015-07-21                                   Toxic Games
# 4          2021.0  2021-08-19  MachineGames, Nightdive Studios, id Software
# ...           ...         ...                                           ...
# 9681       2020.0  2020-10-06                                     Valorware
# 9682       2020.0  2020-10-06                                     Valorware
# 9683       2018.0  2018-06-12                               Skobbejak Games
# 9684       2018.0  2018-06-12                               Skobbejak Games
# 9685       2021.0  2021-11-17                                   Tinimations
#
#                                      Genre         Features     Size  \
# 0                                   Action  PS Plus, PS Now   109.00
# 1                                   Action           PS Now   127.00
# 2                       Puzzle, Platformer              NaN  2682.88
# 3                       Puzzle, Platformer          PS Plus  1945.60
# 4                     First Person Shooter              NaN      NaN
# ...                                    ...              ...      ...
# 9681  Open World, Action-RPG, Role Playing              NaN   653.00
# 9682  Open World, Action-RPG, Role Playing              NaN   653.00
# 9683         Puzzle, Adventure, Platformer              NaN  2170.88
# 9684         Puzzle, Adventure, Platformer              NaN  2170.88
# 9685                                   NaN        Cross-Buy      NaN
#
#                     Medium Hardware CompletionTime(Hours)  is_Digital_game  \
# 0                      NaN      NaN                   NaN                0
# 1             Digital only      NaN                   NaN                0
# 2             Digital only      NaN                   NaN                0
# 3             Digital only      NaN                    34                0
# 4     Physical and Digital      NaN                   NaN                0
# ...                    ...      ...                   ...              ...
# 9681  Physical and Digital      NaN                   NaN                0
# 9682          Digital only      NaN                   NaN                0
# 9683          Digital only      NaN                   NaN                0
# 9684          Digital only      NaN                   NaN                0
# 9685          Digital only      NaN                   NaN                0
#
#       is_Physical_game                                 OfficialWebsite
# 0                    0        http://www.sidelineamusements.com/qbert/
# 1                    0        http://www.sidelineamusements.com/qbert/
# 2                    0                           http://qube-game.com/
# 3                    0                           http://qube-game.com/
# 4                    0              https://bethesda.net/en/game/quake
# ...                ...                                             ...
# 9681                 0  https://valorware.squarespace.com/9th-dawn-iii
# 9682                 0  https://valorware.squarespace.com/9th-dawn-iii
# 9683                 0   http://skobbejakgames.com/n-verlore-verstand/
# 9684                 0   http://skobbejakgames.com/n-verlore-verstand/
# 9685                 0                                             NaN
#
# [9686 rows x 16 columns]

# %% [markdown]
# # EDA

# %%
data_import.dtypes
# Out:
# ID                                int64
# GamePSID                          int64
# GameName                         object
# Publisher                        object
# ReleaseYear                     float64
# ReleaseDate              datetime64[ns]
# Developer                        object
# Genre                            object
# Features                         object
# Size                            float64
# Medium                           object
# Hardware                         object
# CompletionTime(Hours)            object
# is_Digital_game                   int64
# is_Physical_game                  int64
# OfficialWebsite                  object
# dtype: object

# %% [markdown]
# ## Averages

# %%
games = data_import
#games['Size'].mean()
#stats.trim_mean(games['Size'], 0.4)
games['Size'].median()
# Out:
# 1392.64

# %% [markdown]
# ## Numerical column describe

# %%
data_import.describe()
# Out:
#                 ID      GamePSID  ReleaseYear          Size  is_Digital_game  \
# count  9686.000000   9686.000000  8952.000000  7.666000e+03           9686.0
# mean   4843.500000   7450.627813  2018.515304  5.207188e+03              0.0
# std    2796.251688   4434.041993     2.014025  1.880542e+04              0.0
# min       1.000000  -5590.000000  2009.000000  1.100000e+01              0.0
# 25%    2422.250000   5108.250000  2017.000000  3.922500e+02              0.0
# 50%    4843.500000   7972.500000  2019.000000  1.392640e+03              0.0
# 75%    7264.750000  10749.750000  2020.000000  4.710400e+03              0.0
# max    9686.000000  14229.000000  2022.000000  1.002496e+06              0.0
#
#        is_Physical_game
# count            9686.0
# mean                0.0
# std                 0.0
# min                 0.0
# 25%                 0.0
# 50%                 0.0
# 75%                 0.0
# max                 0.0

# %% [markdown]
# ### Date analysis

# %%
px.histogram(games, x="ReleaseYear")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/env/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# ~/anaconda3/envs/env/lib/python3.9/site-packages/plotly/basedatatypes.py in _ipython_display_(self)
#     842
#     843         if pio.renderers.render_on_display and pio.renderers.default:
# --> 844             pio.show(self)
#     845         else:
#     846             print(repr(self))
#
# ~/anaconda3/envs/env/lib/python3.9/site-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     395
#     396         if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 397             raise ValueError(
#     398                 "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     399             )
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'alignmentgroup': 'True',
#               'bingroup': 'x',
#               'hovertemplate': 'ReleaseYear=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'offsetgroup': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'type': 'histogram',
#               'x': array([2015., 2015., 2018., ..., 2018., 2018., 2021.]),
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'ReleaseYear'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'count'}}}
# })

# %%
data_import["ReleaseDate"].hist()
# Out:
# <AxesSubplot:>
